# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\nstej\Downloads\Complete-Feature-Engineering-master\Complete-Feature-Engineering-master\mercedesbenz.csv", usecols = ['X1','X2'])

# %%
df.head()
# Out:
#   X1  X2
# 0  v  at
# 1  t  av
# 2  w   n
# 3  t   n
# 4  v   n

# %%
df.shape
# Out:
# (4209, 2)

# %% [markdown]
# One hot encoding

# %%
pd.get_dummies(df).shape
# Out:
# (4209, 71)

# %%
len(df['X1'].unique())
# Out:
# 27

# %%
len(df['X2'].unique())
# Out:
# 44

# %%
# let's have a look at how many labels

for col in df.columns[0:]:
    print(col, ': ', len(df[col].unique()), ' labels')
# Out:
# X1 :  27  labels
# X2 :  44  labels

# %%
# let's obtain the counts for each one of the labels in variable X2
# let's capture this in a dictionary that we can use to re-map the labels

df.X2.value_counts().to_dict()
# Out:
# {'as': 1659,
#  'ae': 496,
#  'ai': 415,
#  'm': 367,
#  'ak': 265,
#  'r': 153,
#  'n': 137,
#  's': 94,
#  'f': 87,
#  'e': 81,
#  'aq': 63,
#  'ay': 54,
#  'a': 47,
#  't': 29,
#  'k': 25,
#  'i': 25,
#  'b': 21,
#  'ao': 20,
#  'ag': 19,
#  'z': 19,
#  'd': 18,
#  'ac': 13,
#  'g': 12,
#  'ap': 11,
#  'y': 11,
#  'x': 10,
#  'aw': 8,
#  'at': 6,
#  'h': 6,
#  'an': 5,
#  'al': 5,
#  'q': 5,
#  'av': 4,
#  'p': 4,
#  'ah': 4,
#  'au': 3,
#  'am': 1,
#  'j': 1,
#  'l': 1,
#  'o': 1,
#  'af': 1,
#  'aa': 1,
#  'ar': 1,
#  'c': 1}

# %%
# And now let's replace each label in X2 by its count

# first we make a dictionary that maps each label to the counts

df_frequency_map = df.X2.value_counts().to_dict()

# %%
df.head(50)
# Out:
#     X1  X2
# 0    v  at
# 1    t  av
# 2    w   n
# 3    t   n
# 4    v   n
# 5    b   e
# 6    r   e
# 7    l  as
# 8    s  as
# 9    b  aq
# 10   r   r
# 11   r   e
# 12   b  ai
# 13   r   e
# 14   s  as
# 15   l  ak
# 16   r   e
# 17  aa  as
# 18   c   m
# 19   a  ak
# 20   s   m
# 21  aa  as
# 22   r   a
# 23   b   m
# 24   r  ak
# 25   s   m
# 26   l  as
# 27  aa  as
# 28   s  as
# 29   b   m
# 30   v  as
# 31   e  as
# 32   b   m
# 33   s  as
# 34   s  as
# 35   b  ai
# 36   l  as
# 37   v   k
# 38   v  as
# 39   s  as
# 40   l  as
# 41   h  ae
# 42  aa  ai
# 43   s  as
# 44   z  ai
# 45   b   m
# 46   r  ai
# 47  aa   m
# 48   w  av
# 49   j  ai

# %%
# and now we replace X2 labels in the dataset df
df.X2 = df.X2.map(df_frequency_map)
df.head()
# Out:
#   X1   X2
# 0  v    6
# 1  t    4
# 2  w  137
# 3  t  137
# 4  v  137
